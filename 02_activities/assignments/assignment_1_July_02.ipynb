# %%
# import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
np.random.seed(613) # Set random seed for reproducibility
x = np.arange(50)
y = np.random.randint(0, 100, 50) # Generate random data for y

fig, ax = plt.subplots(figsize=(5, 3)) # Create a figure and axis
ax.scatter(x, y) # Create a scatter plot

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.bar(x, y) # Create a bar plot
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.barh(x, y) # Create a horizontal bar plot
# Out:
# <BarContainer object of 50 artists>

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100, 50)

fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y) # Create a line plot

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100, 50)

fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(y) # Create a histogram of y values
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y) # Create a line plot of x and y

ax.set_title('Total growth over time') # Set the title of the plot
ax.set_ylabel('Total growth') # Set the y-axis label
ax.set_xlabel('Years since start') # Set the x-axis label
# Out:
# Text(0.5, 0, 'Years since start')

# %%
# Customizing the plot with different fonts and colors
# Define font properties for the title and labels with dictionaries
font1 = {'family': 'sans-serif', 'color':'blue', 'size': 20}
font2 = {'family': 'monospace', 'color':'green', 'size': 14}

fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

ax.set_title('Total growth over time', fontdict = font1, loc = 'left') # loc = 'left' aligns the title to the left
ax.set_ylabel('Total growth', fontdict = font2  )
ax.set_xlabel('Years since start', fontdict = font2)
# Out:
# Text(0.5, 0, 'Years since start')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x, 
           y, 
           marker = '*',
           color = 'indigo') # Create a scatter plot with custom marker and color

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y, marker = '*',
           color = 'indigo',
           linestyle = '--',
           linewidth = 2,) # Create a line plot with custom marker, color, linestyle, and linewidth
# fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y, marker = '*',
        color = '#7425B9', # Using a hex color code
        linestyle = '--',
        linewidth = 2,
        markersize = 12,
        markeredgecolor = '#FA9359',
        markerfacecolor = '#000000') # Create a line plot with custom marker, color, linestyle, linewidth, markersize, markeredgecolor, and markerfacecolor

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y, marker = '*',
        color = '#7425B9',
        linestyle = '--',
        linewidth = 2,
        markersize = 12,
        markeredgecolor = '#FA9359',
        markerfacecolor = '#000000')

ax.grid(axis='y', color='gray', linestyle='--', linewidth=0.5) # Customize the grid for the y-axis
ax.grid(axis='x', color='blue', linestyle='--', linewidth=1.5) # Customize the grid for the x-axis

# %%
# Example of stacked bar chart with custom colors and bold y-axis labels taken from provided code snippet, can't trace the origin
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd
 
# y-axis in bold
rc('font', weight='bold')
 
# Values of each group
bars1 = [12, 28, 1, 8, 22]
bars2 = [28, 7, 16, 14, 10]
bars3 = [25, 3, 23, 25, 17]
 
# Heights of bars1 + bars2
bars = np.add(bars1, bars2).tolist()
 
# The position of the bars on the x-axis
r = [0,1,2,3,4]
 
# Names of group and bar width
names = ['A','B','C','D','E']
barWidth = 1
 
# Create brown bars
plt.bar(r, bars1, color="#eb1220", edgecolor='white', width=barWidth)
# Create green bars (middle), on top of the first ones
plt.bar(r, bars2, bottom=bars1, color="#3d2d7f", edgecolor='white', width=barWidth)
# Create green bars (top)
plt.bar(r, bars3, bottom=bars, color="#14be2d", edgecolor='white', width=barWidth)
 
# Custom X axis
plt.xticks(r, names, fontweight='bold')
plt.xlabel("group")
 
# Show graphic
plt.show()
